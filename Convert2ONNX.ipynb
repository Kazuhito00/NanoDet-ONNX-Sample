# %% [markdown]
# # PyTorch Lightningインストール

# %%
# !pip install pytorch_lightning
# Out:
# ...
#      |████████████████████████████████| 923 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 282 kB 18.7 MB/s
# ...
#      |████████████████████████████████| 636 kB 51.0 MB/s
# ...
#      |████████████████████████████████| 829 kB 31.7 MB/s
# ...
#      |████████████████████████████████| 119 kB 36.7 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 46.1 MB/s
# ...
#      |████████████████████████████████| 142 kB 72.5 MB/s
# ...
#      |████████████████████████████████| 294 kB 56.8 MB/s
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=5949d5f90387089e7986e1122b9b298bd839733752ceb68452af1ea2f910eea5
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built future
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: future
# ...

# %% [markdown]
# # NanoDetリポジトリクローン

# %%
# !git clone https://github.com/RangiLyu/nanodet.git
# Out:
# Cloning into 'nanodet'...
# remote: Enumerating objects: 2246, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 2246 (delta 21), reused 37 (delta 9), pack-reused 2162
# Receiving objects: 100% (2246/2246), 5.27 MiB | 20.92 MiB/s, done.
# Resolving deltas: 100% (1265/1265), done.

# %%
# %cd nanodet
# Out:
# /content/nanodet

# %% [markdown]
# # 学習済モデルダウンロード

# %%
import gdown

gdown.download('https://drive.google.com/uc?id=1ZkYucuLusJrCb_i63Lid0kYyyLvEiGN3', 'nanodet_m_320.ckpt', quiet=False)
gdown.download('https://drive.google.com/uc?id=1jY-Um2VDDEhuVhluP9lE70rG83eXQYhV', 'nanodet_m_416.ckpt', quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZkYucuLusJrCb_i63Lid0kYyyLvEiGN3
# To: /content/nanodet/nanodet_m_320.ckpt
# 3.99MB [00:00, 181MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1jY-Um2VDDEhuVhluP9lE70rG83eXQYhV
# To: /content/nanodet/nanodet_m_416.ckpt
# 3.97MB [00:00, 211MB/s]
# 'nanodet_m_416.ckpt'

# %% [markdown]
# # ONNX変換

# %%
# !cp tools/export_onnx.py ./

# %%
# !python export_onnx.py \
    --cfg_path=config/nanodet-m.yml \
    --model_path=nanodet_m_320.ckpt \
    --out_path=nanodet_m_320.onnx
# Out:
# model size is  1.0x
# init weights...
# Downloading: "https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth" to /root/.cache/torch/hub/checkpoints/shufflenetv2_x1-5666bf0f80.pth
# 100% 8.79M/8.79M [00:00<00:00, 72.6MB/s]
# => loading pretrained model https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth
# Finish initialize NanoDet Head.
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...

# %%
# !python export_onnx.py \
    --cfg_path=config/nanodet-m-416.yml \
    --model_path=nanodet_m_416.ckpt \
    --out_path=nanodet_m_416.onnx
# Out:
# model size is  1.0x
# init weights...
# => loading pretrained model https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth
# Finish initialize NanoDet Head.
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# ...

# %% [markdown]
# # ONNX最適化

# %%
# !pip install onnx-simplifier
# Out:
# ...
#      |████████████████████████████████| 12.3 MB 178 kB/s
# ...
#      |████████████████████████████████| 466 kB 53.8 MB/s
# ...
#      |████████████████████████████████| 4.5 MB 69.7 MB/s
# ...
#   Created wheel for onnx-simplifier: filename=onnx_simplifier-0.3.6-py3-none-any.whl size=12873 sha256=62507c1be827374c0ad18d6eeb38569b523181a3eaee2bf2e7e9e969297ed3b9
#   Stored in directory: /root/.cache/pip/wheels/0c/47/80/8eb21098e22c19d60b1c14021ee67442b4ad2d7991fdad46ba
# Successfully built onnx-simplifier
# ...

# %%
# !python -m onnxsim nanodet_m_320.onnx nanodet_m_320.onnx
# Out:
# Simplifying...
# Checking 0/3...
# Checking 1/3...
# Checking 2/3...
# Ok!

# %%
# !python -m onnxsim nanodet_m_416.onnx nanodet_m_416.onnx
# Out:
# Simplifying...
# Checking 0/3...
# Checking 1/3...
# Checking 2/3...
# Ok!
